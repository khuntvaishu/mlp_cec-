# %%
import numpy as np

import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Desktop/Stock.csv")

# %%
print(data)
# Out:
#     Ticker       Date        Open        High         Low       Close  \
# 0     AAPL   2/7/2023  150.639999  155.229996  150.639999  154.649994
# 1     AAPL   2/8/2023  153.880005  154.580002  151.169998  151.919998
# 2     AAPL   2/9/2023  153.779999  154.330002  150.419998  150.869995
# 3     AAPL  2/10/2023  149.460007  151.339996  149.220001  151.009995
# 4     AAPL  2/13/2023  150.949997  154.259995  150.919998  153.850006
# ..     ...        ...         ...         ...         ...         ...
# 243   GOOG   5/1/2023  107.720001  108.680000  107.500000  107.709999
# 244   GOOG   5/2/2023  107.660004  107.730003  104.500000  105.980003
# 245   GOOG   5/3/2023  106.220001  108.129997  105.620003  106.120003
# 246   GOOG   5/4/2023  106.160004  106.300003  104.699997  105.209999
# 247   GOOG   5/5/2023  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close    Volume
# 0    154.414230  83322600
# 1    151.688400  64120100
# 2    150.639999  56007100
# ...

# %%
data.head(7)
# Out:
#   Ticker       Date        Open        High         Low       Close  \
# 0   AAPL   2/7/2023  150.639999  155.229996  150.639999  154.649994
# 1   AAPL   2/8/2023  153.880005  154.580002  151.169998  151.919998
# 2   AAPL   2/9/2023  153.779999  154.330002  150.419998  150.869995
# 3   AAPL  2/10/2023  149.460007  151.339996  149.220001  151.009995
# 4   AAPL  2/13/2023  150.949997  154.259995  150.919998  153.850006
# 5   AAPL  2/14/2023  152.119995  153.770004  150.860001  153.199997
# 6   AAPL  2/15/2023  153.110001  155.500000  152.880005  155.330002
#
#     Adj Close    Volume
# 0  154.414230  83322600
# 1  151.688400  64120100
# 2  150.639999  56007100
# 3  151.009995  57450700
# 4  153.850006  62199000
# 5  153.199997  61707600
# 6  155.330002  65573800

# %%
data.tail(7)
# Out:
#     Ticker       Date        Open        High         Low       Close  \
# 241   GOOG  4/27/2023  105.230003  109.150002  104.419998  108.370003
# 242   GOOG  4/28/2023  107.800003  108.290001  106.040001  108.220001
# 243   GOOG   5/1/2023  107.720001  108.680000  107.500000  107.709999
# 244   GOOG   5/2/2023  107.660004  107.730003  104.500000  105.980003
# 245   GOOG   5/3/2023  106.220001  108.129997  105.620003  106.120003
# 246   GOOG   5/4/2023  106.160004  106.300003  104.699997  105.209999
# 247   GOOG   5/5/2023  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close    Volume
# 241  108.370003  38235200
# 242  108.220001  23957900
# 243  107.709999  20926300
# 244  105.980003  20343100
# 245  106.120003  17116300
# 246  105.209999  19780600
# 247  106.214996  20705300

# %%
data.loc[1] # fatching first row
# Out:
# Ticker             AAPL
# Date           2/8/2023
# Open         153.880005
# High         154.580002
# Low          151.169998
# Close        151.919998
# Adj Close      151.6884
# Volume         64120100
# Name: 1, dtype: object

# %%
data.info() #getting information about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ticker     248 non-null    object
#  1   Date       248 non-null    object
#  2   Open       248 non-null    float64
#  3   High       248 non-null    float64
#  4   Low        248 non-null    float64
#  5   Close      248 non-null    float64
#  6   Adj Close  248 non-null    float64
#  7   Volume     248 non-null    int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 15.6+ KB

# %%
#droping the null data
data.dropna()
# Out:
#     Ticker       Date        Open        High         Low       Close  \
# 0     AAPL   2/7/2023  150.639999  155.229996  150.639999  154.649994
# 1     AAPL   2/8/2023  153.880005  154.580002  151.169998  151.919998
# 2     AAPL   2/9/2023  153.779999  154.330002  150.419998  150.869995
# 3     AAPL  2/10/2023  149.460007  151.339996  149.220001  151.009995
# 4     AAPL  2/13/2023  150.949997  154.259995  150.919998  153.850006
# ..     ...        ...         ...         ...         ...         ...
# 243   GOOG   5/1/2023  107.720001  108.680000  107.500000  107.709999
# 244   GOOG   5/2/2023  107.660004  107.730003  104.500000  105.980003
# 245   GOOG   5/3/2023  106.220001  108.129997  105.620003  106.120003
# 246   GOOG   5/4/2023  106.160004  106.300003  104.699997  105.209999
# 247   GOOG   5/5/2023  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close    Volume
# 0    154.414230  83322600
# 1    151.688400  64120100
# 2    150.639999  56007100
# ...

# %%
#replace value to null values
data.fillna(30)
# Out:
#     Ticker       Date        Open        High         Low       Close  \
# 0     AAPL   2/7/2023  150.639999  155.229996  150.639999  154.649994
# 1     AAPL   2/8/2023  153.880005  154.580002  151.169998  151.919998
# 2     AAPL   2/9/2023  153.779999  154.330002  150.419998  150.869995
# 3     AAPL  2/10/2023  149.460007  151.339996  149.220001  151.009995
# 4     AAPL  2/13/2023  150.949997  154.259995  150.919998  153.850006
# ..     ...        ...         ...         ...         ...         ...
# 243   GOOG   5/1/2023  107.720001  108.680000  107.500000  107.709999
# 244   GOOG   5/2/2023  107.660004  107.730003  104.500000  105.980003
# 245   GOOG   5/3/2023  106.220001  108.129997  105.620003  106.120003
# 246   GOOG   5/4/2023  106.160004  106.300003  104.699997  105.209999
# 247   GOOG   5/5/2023  105.320000  106.440002  104.738998  106.214996
#
#       Adj Close    Volume
# 0    154.414230  83322600
# 1    151.688400  64120100
# 2    150.639999  56007100
# ...

# %%
#update spacific column
new = data["Open"].fillna("100")

# %%
print(new)
# Out:
# 0      150.639999
# 1      153.880005
# 2      153.779999
# 3      149.460007
# 4      150.949997
#           ...
# 243    107.720001
# 244    107.660004
# 245    106.220001
# 246    106.160004
# 247    105.320000
# Name: Open, Length: 248, dtype: float64

# %%
data.describe() #quick statistic summary of you
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  248.000000  248.000000  248.000000  248.000000  248.000000
# mean   215.252093  217.919662  212.697452  215.381674  215.362697
# std     91.691315   92.863023   90.147881   91.461989   91.454750
# min     89.540001   90.129997   88.860001   89.349998   89.349998
# 25%    135.235004  137.440004  134.822495  136.347498  136.347498
# 50%    208.764999  212.614998  208.184998  209.920006  209.920006
# 75%    304.177506  307.565002  295.437500  303.942505  303.942505
# max    372.410004  373.829987  361.739990  366.829987  366.829987
#
#              Volume
# count  2.480000e+02
# mean   3.208210e+07
# std    2.233590e+07
# min    2.657900e+06
# 25%    1.714180e+07
# 50%    2.734000e+07
# 75%    4.771772e+07
# max    1.133164e+08

# %%
data.T #transpose
# Out:
#                   0           1           2           3           4    \
# Ticker           AAPL        AAPL        AAPL        AAPL        AAPL
# Date         2/7/2023    2/8/2023    2/9/2023   2/10/2023   2/13/2023
# Open       150.639999  153.880005  153.779999  149.460007  150.949997
# High       155.229996  154.580002  154.330002  151.339996  154.259995
# Low        150.639999  151.169998  150.419998  149.220001  150.919998
# Close      154.649994  151.919998  150.869995  151.009995  153.850006
# Adj Close   154.41423    151.6884  150.639999  151.009995  153.850006
# Volume       83322600    64120100    56007100    57450700    62199000
#
#                   5           6           7           8           9    ...  \
# Ticker           AAPL        AAPL        AAPL        AAPL        AAPL  ...
# Date        2/14/2023   2/15/2023   2/16/2023   2/17/2023   2/21/2023  ...
# Open       152.119995  153.110001  153.509995  152.350006  150.199997  ...
# ...

# %%
data.plot()
plt.show()

# %%
# SCATTER 
data.plot(kind="scatter",x="High",y="Volume",c='r',s=20,alpha=0.9,marker='*') #c=color,s=size,alpha=opacity
plt.show()

# %%
data.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# MEAN
mean = data['High'].mean()
print(mean)
# Out:
# 217.9196617685081

# %%
mode = data['High'].mode()
print(mode)
# Out:
# 0       90.129997
# 1       90.449997
# 2       91.199997
# 3       91.449997
# 4       92.129997
#           ...
# 243    362.880005
# 244    363.750000
# 245    364.179993
# 246    368.190002
# 247    373.829987
# Name: High, Length: 248, dtype: float64

# %%
median= data['High'].median()
print(median)
# Out:
# 212.6149979

# %%
plt.subplot(1,2,1) # row column index
plt.title('s1')
plt.plot(data['Open'])
plt.xlabel('x-axis')
plt.ylabel('y-axis')


plt.subplot(1,2,2)
plt.plot(data['Volume'])
plt.title('s2')
plt.xlabel('x-axis')
plt.ylabel('y-axis')


plt.suptitle('SuperTitle')
# Out:
# Text(0.5, 0.98, 'SuperTitle')

# %%
# bar chart
plt.bar(data['High'],data['Low'])
# Out:
# <BarContainer object of 248 artists>

# %%
plt.barh(data['High'],data['Low'])
# Out:
# <BarContainer object of 248 artists>
